# %% [markdown]
# # return
#
# Purpose: Sends a value back to the caller (the place where the function was called).
#
# Effect: Allows you to use the result later in your program.
#
# Use case: Essential when you want to store, calculate, or pass around values.

# %%
def square(x):
    return x * x

result = square(4)
print(result)   # prints 16
# Out:
# 16
